# %% [markdown]
# ## 온라인 학습활동 과제 10.
# ## 보스톤 주택가격 데이터(Boston House Prices) 시각화

# %% [markdown]
# ### 빅데이터전공 20175327 이연희

# %% [markdown]
# ### 1. https://www.kaggle.com/에 대해 조사하여 마크다운으로 설명하세요.

# %% [markdown]
# - 캐글(Kaggle, https://www.kaggle.com)
#     - 데이터 사이언스 경진 대회 플랫폼이다.
#     - 기업에서 문제와 이에 대한 데이터를 제공하면 전세계 데이터 과학자들이 해당 문제의 해결법을 놓고 경쟁을 벌인다.
#     - 기업은 데이터와 상금을 제공하고 데이터 과학자들은 경진 대회를 통해 해결책을 제공함으로써 기업은 해결책을, 데이터 과학자는 상금을 가져가는 데이터 경쟁 플랫폼이라 할 수 있다.
#     - 캐글은 다양한 데이터셋(Dataset)을 제공하고 로컬 환경이나 캐글의 커널 메뉴를 통해 직접 분석하고 결과를 제출할 수 있는 환경을 제공한다.

# %% [markdown]
# ### 2. 보스톤 주택가격 데이터(Boston House Prices) 시각화

# %% [markdown]
# #### (1) Boston House Prices dataset 사용
# #### https://www.kaggle.com/에서 검색하여 파일을 받아 시각화에 이용, 데이터 특징 설명을 정리하여 마크다운으로 포함

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import sklearn.datasets as ds
import mglearn
# Out:
# D:\python\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# D:\python\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# #### 데이터 불러오기

# %%
names = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']

boston = ds.load_boston()
df = pd.DataFrame(data=np.c_[boston['data'], boston['target']], columns=names)

display(df)
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %% [markdown]
# ### 데이터 특징 정리

# %% [markdown]
# - 데이터명 : Boston Housing Price (보스턴 주택 가격 데이터)
# - 인스턴스 수 : 506 개
# - 특징 개수 :  14 개
#
# - 데이터 설명 : 1978년 보스턴 주택 가격에 대한 데이터이며 506개 타운의 주택가격 중앙값 및 주택의 여러가진 요건들과 주택의 가격 정보가 포함되어 있다.
#     해당 데이터는 주택의 가격에 영향을 미치는 요소의 분석 목적으로 사용될 수 있으며 회귀분석 등의 분석에 활용될 수 있다.
#     보스턴 주택 데이터는 여러 개의 측정지표들 (ex. 범죄율, 학생/교사 비율 등)을 포함한, 보스턴 인근의 주택 가격의 중앙값(median value)이며 14개의 특징을 포함하고 있다.
#     보스턴 주택 가격 데이터는 다음과 같이 구성되어있다.
#
#
# - 타겟 데이터
#     - 1978 보스턴 주택 가격
#     - 506개 타운의 주택 가격 중앙값 (단위 1,000 달러)
#
#
# - 특징 데이터
#     - CRIM: 자치시(town) 별 1인당 범죄율
#     - INDUS: 비소매상업지역이 점유하고 있는 토지의 비율
#     - NOX: 10ppm 당 농축 일산화질소
#     - RM: 주택 1가구당 평균 방의 개수
#     - LSTAT: 인구 중 하위계층의 비율(%)
#     - B: 인구 중 흑인 비율
#     - PTRATIO: 자치시(town)별 학생/교사 비율
#     - ZN: 25,000 평방피트를 초과하는 거주지역의 비율
#     - CHAS: 찰스강의 경계에 위치 유/무 (강의 경계에 위치한 경우는 1, 아니면 0)
#     - AGE: 1940년 이전에 건축된 주택의 비율
#     - RAD: 방사형 고속도로까지의 거리
#     - DIS: 5개의 보스턴 직업센터까지의 거리
#     - TAX: 10,000 달러 당 재산세율
#     - MEDV: 본인 소유의 주택가격(중앙값) (단위:$1,000)

# %% [markdown]
# ### (2) 데이터의 구조 확인

# %%
print("============================== 데이터 설명 확인 ==========================\n", boston['DESCR'])
print("============================== 특성의 이름 ============================== \n {}".format(boston['feature_names']))
print("============================== 데이터 타입 ============================== \n {}".format(type(boston['data'])))
print("============================== 데이터 크기 ============================== \n {}".format(boston['data'].shape))
print("============================== 타겟의 타입 ============================== \n {}".format(type(boston['target'])))
print("============================== 타겟 ===================================== \n {}".format(boston['target']))
# Out:
# ============================== 데이터 설명 확인 ==========================
#  .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
# ...

# %% [markdown]
# ### (3) 기초통계요약 확인

# %%
print("==============================  통계요약 확인 ==============================")
display(df.describe())
# Out:
# ==============================  통계요약 확인 ==============================
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# ...

# %% [markdown]
# ### (4) 모든 특징들에 대한 상관계수 확인

# %%
corr=df.corr(method='pearson')
display(corr)
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [markdown]
# ### (5) 주택가격(medv)과 다른 특징들과의 상관계수 확인

# %%
corrMEDV = corr["MEDV"]
display(corrMEDV)
# Out:
# CRIM      -0.388305
# ZN         0.360445
# INDUS     -0.483725
# CHAS       0.175260
# NOX       -0.427321
# RM         0.695360
# AGE       -0.376955
# DIS        0.249929
# RAD       -0.381626
# TAX       -0.468536
# PTRATIO   -0.507787
# B          0.333461
# LSTAT     -0.737663
# MEDV       1.000000
# Name: MEDV, dtype: float64

# %% [markdown]
# #### Scatter Plot으로 확인

# %%
for column in df.columns:
    df.plot.scatter(x='MEDV',y=column)

# %% [markdown]
# ### (6) rm,ptratio, lstat, medv 4개 속성만 사용

# %%
boston_4 = df[["RM","PTRATIO","LSTAT","MEDV"]]

# %% [markdown]
# ### (7) 4개 속성에 대한 histogram, boxplot 확인

# %% [markdown]
# #### histogram 확인

# %%
boston_4.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B8C9C7A0F0>,
# ...
#       dtype=object)

# %% [markdown]
# #### boxplot 확인

# %%
boston_4.boxplot()

# %% [markdown]
# ### (8) 4개 속성에 대한 scatter plot (산점도 행렬 : Scatterplot Matrices)

# %%
pd.plotting.scatter_matrix(boston_4,s=60,figsize=(15, 15),marker='o',diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B8CFDCF160>,
# ...
#       dtype=object)
